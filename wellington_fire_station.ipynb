# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.8     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.1
# ✔ readr   2.1.2     ✔ forcats 0.5.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
wellington_fire_stations <- read.csv('wellington_fire_stations.csv')
wellington_fire_stations
# Out:
#    OBJECTID NAME
# 1   1       Hutt  City Fire Station
# 2   2       New Zealand Fire Service Newlands
# 3   3       New Zealand Fire Service Seaview
# 4   4       New Zealand Fire Service Silverstream
# 5   5       New Zealand Fire Service Martinborough
# 6   6       New Zealand Fire Service Porirua
# 7   7       New Zealand Fire Service Johnsonville
# 8   8       New Zealand Fire Service Masterton
# 9   9       New Zealand Fire Service Rimutaka
# 10 10       New Zealand Fire Service Eastbourne
# 11 11       New Zealand Fire Service Plimmerton
# 12 12       New Zealand Fire Service Kilbirnie
# 13 13       New Zealand Fire Service Wainuiomata
# 14 14       New Zealand Fire Service Brooklyn
# 15 15       New Zealand Fire Service Paekakariki
# 16 16       New Zealand Fire Service Kandallah
# 17 17       New Zealand Fire Service Karori
# 18 18       New Zealand Fire Service Thorndon
# 19 19       New Zealand Fire Service Trentham
# 20 20       New Zealand Fire Service Paraparaumu
# ...
